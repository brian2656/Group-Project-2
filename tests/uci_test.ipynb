# %% [markdown]
# ## Install required dependencies and read in csv data

# %%
# Import dependencies
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, balanced_accuracy_score
from sklearn.model_selection import train_test_split
import models as tests
from sklearn.utils import resample
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in html data 
red_df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv',sep=';')
white_df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv',sep=';')

red_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
# Set column for red and white
red_df['wine_type'] = 'red'
white_df['wine_type'] = 'white'

# %%
# combine red and white dataframes
df = pd.concat([red_df, white_df], axis=0)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality wine_type
# 0         9.4        5       red
# 1         9.8        5       red
# 2         9.8        5       red
# 3         9.8        6       red
# 4         9.4        5       red
# ...       ...      ...       ...
# 4893     11.2        6     white
# 4894      9.6        5     white
# 4895      9.4        6     white
# 4896     12.8        7     white
# 4897     11.8        6     white
#
# [6497 rows x 13 columns]

# %% [markdown]
# ## Create dataframes for baseline scores and processed scores

# %%
# Read in CSV data to run initial models for baseline results
df_initial = df.copy()

# Check column names, null values and Dtypes
df_initial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  wine_type             6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 710.6+ KB

# %%
# Read in CSV data to attempt sampling for better results
df_sample = df.copy()

# Check column names, null values and Dtypes
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  wine_type             6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 710.6+ KB

# %% [markdown]
# ## Run initial data through models to get initial baseline scores

# %%
# set X and y variables to determine initial baseline score
X0 = df_initial.drop(columns=['quality','wine_type'])
y0 = df_initial['quality']

# %%
# Split data into training and testing data
X_train0,X_test0,y_train0,y_test0 = train_test_split(X0,y0,random_state=13)

# %%
# Run initial data through many_models to get baseline scores
# Run data through 'many_models_full' function to determine scores and initial parameter optimization for Random Forest Classifier Model
models_full_preprocess = tests.many_models_full(X_train0,y_train0,X_test0,y_test0)
# Out:
# Random Forest
# Test Accuracy: 0.6726153846153846
# balanced test score: 0.3510074145712444
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         7
#            4       0.64      0.15      0.24        48
#            5       0.70      0.74      0.72       528
#            6       0.64      0.77      0.70       705
#            7       0.71      0.46      0.56       282
#            8       0.95      0.33      0.49        54
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.67      1625
#    macro avg       0.52      0.35      0.39      1625
# weighted avg       0.68      0.67      0.66      1625
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Gradient Boost
# Test Accuracy: 0.5889230769230769
# balanced test score: 0.26994130770726515
#
#  classification report:
#                precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         7
#            4       0.12      0.04      0.06        48
#            5       0.63      0.67      0.65       528
#            6       0.57      0.71      0.64       705
#            7       0.59      0.31      0.41       282
#            8       0.89      0.15      0.25        54
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.59      1625
#    macro avg       0.40      0.27      0.29      1625
# weighted avg       0.59      0.59      0.57      1625
#
#
# Logistic Regression
# Test Accuracy: 0.540923076923077
# balanced test score: 0.21556138896564428
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         7
#            4       0.00      0.00      0.00        48
#            5       0.58      0.63      0.60       528
#            6       0.53      0.71      0.60       705
#            7       0.46      0.17      0.25       282
#            8       0.00      0.00      0.00        54
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.54      1625
#    macro avg       0.22      0.22      0.21      1625
# weighted avg       0.50      0.54      0.50      1625
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Poly Support Vector
# Test Accuracy: 0.5347692307692308
# Balanced test score: 0.2061550151975684
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         7
#            4       0.00      0.00      0.00        48
#            5       0.62      0.54      0.58       528
#            6       0.50      0.78      0.61       705
#            7       0.52      0.12      0.20       282
#            8       0.00      0.00      0.00        54
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.53      1625
#    macro avg       0.24      0.21      0.20      1625
# weighted avg       0.51      0.53      0.49      1625
#
#
# ADA low estimators
# Test Accuracy: 0.344
# balanced test score: 0.23277674706246135
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.01      0.71      0.03         7
#            4       0.00      0.00      0.00        48
#            5       0.43      0.52      0.47       528
#            6       0.44      0.40      0.42       705
#            7       0.00      0.00      0.00       282
#            8       0.00      0.00      0.00        54
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.34      1625
#    macro avg       0.13      0.23      0.13      1625
# weighted avg       0.33      0.34      0.33      1625
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ADA
# Test Accuracy: 0.22707692307692307
# balanced test score: 0.2492914380452374
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.01      0.71      0.03         7
#            4       0.04      0.42      0.07        48
#            5       0.49      0.27      0.34       528
#            6       0.45      0.25      0.32       705
#            7       0.42      0.10      0.16       282
#            8       0.00      0.00      0.00        54
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.23      1625
#    macro avg       0.20      0.25      0.13      1625
# weighted avg       0.43      0.23      0.28      1625
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# SVC Sigmoid
# Test Accuracy: 0.4338461538461538
# balanced test score: 0.20026135212305426
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         7
#            4       0.08      0.17      0.11        48
#            5       0.47      0.46      0.46       528
#            6       0.46      0.56      0.50       705
#            7       0.43      0.22      0.29       282
#            8       0.00      0.00      0.00        54
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.43      1625
#    macro avg       0.21      0.20      0.20      1625
# weighted avg       0.43      0.43      0.42      1625
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# non-tuned models dataframe
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             1.000000    0.672615             0.351007
# Gradient Boosting         0.713054    0.588923             0.269941
# ADA boost                 0.234606    0.227077             0.249291
# ADA Low Estimators        0.366174    0.344000             0.232777
# Logistic Regression       0.542693    0.540923             0.215561
# SVC poly                  0.580665    0.534769             0.206155
# SVC sigmoid               0.433703    0.433846             0.200261
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.648993
# Gradient Boosting               0.430798
# ADA boost                      -0.048019
# ADA Low Estimators             -0.046457
# Logistic Regression             0.015383
# SVC poly                        0.086844
# SVC sigmoid                    -0.004813
#
# Random Forest Parameter Tuning:
#
# best depth balanced test score:
#     train_score  test_score  max_depth
# 16     0.996871    0.355129         17
# 18     1.000000    0.353778         19
# 17     0.998972    0.352664         18
# 15     0.992152    0.346506         16
# 14     0.982271    0.339341         15
# max depths:
# [17, 19, 18, 16, 15]
#
# best min leaf balanced test score:
#    train_score  test_score  min_leaf
# 0     0.726305    0.338284         2
# 1     0.529893    0.296255         3
# 2     0.461255    0.284575         4
# 3     0.409277    0.271597         5
# 4     0.384625    0.266629         6
# best min leaf
# [2, 3, 4, 5, 6]
#
# best n_estimators balanced test score:
#     train_score  test_score  n_estimators
# 47     0.724589    0.338521            96
# 48     0.724518    0.337947            98
# 40     0.731244    0.337778            82
# 42     0.730056    0.336157            86
# 43     0.722710    0.336122            88
# best n_estimators
# [96, 98, 82, 86, 88]
#
# best min_split balanced test score:
#    train_score  test_score  min_split
# 0     0.724589    0.338521          2
# 1     0.724589    0.338521          4
# 2     0.612023    0.314986          6
# 3     0.525715    0.298309          8
# 4     0.483746    0.290501         10
# best min_split
# [2, 4, 6, 8, 10]
#
# best max_leaf balanced test score:
#     train_score  test_score  max_leaf
# 63     0.370864    0.261023       191
# 65     0.373183    0.260888       197
# 58     0.357369    0.260549       176
# 64     0.371468    0.260348       194
# 57     0.356051    0.260246       173
# best max leaf
# [191, 197, 176, 194, 173]
#
#
# Test best Random Forest Tuned Parameters scores
#
#
# Test Best Random Forest Tuned Parameters Scores
# Test Accuracy: 0.6178461538461538
# balanced test score: 0.2610234820341203
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         7
#            4       0.00      0.00      0.00        48
#            5       0.66      0.71      0.68       528
#            6       0.59      0.76      0.66       705
#            7       0.65      0.32      0.43       282
#            8       1.00      0.04      0.07        54
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.62      1625
#    macro avg       0.41      0.26      0.26      1625
# weighted avg       0.61      0.62      0.59      1625
#
# updated comparison DataFrame
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             1.000000    0.672615             0.351007
# Gradient Boosting         0.713054    0.588923             0.269941
# Test Random Forest        0.763957    0.617846             0.261023
# ADA boost                 0.234606    0.227077             0.249291
# ADA Low Estimators        0.366174    0.344000             0.232777
# Logistic Regression       0.542693    0.540923             0.215561
# SVC poly                  0.580665    0.534769             0.206155
# SVC sigmoid               0.433703    0.433846             0.200261
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.648993
# Gradient Boosting               0.430798
# Test Random Forest              0.109841
# ADA boost                      -0.048019
# ADA Low Estimators             -0.046457
# Logistic Regression             0.015383
# SVC poly                        0.086844
# SVC sigmoid                    -0.004813
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# best results:
#             n_estimators  max_depth  min_split  max_leaf  min_samples_leaf  \
# test_score
# 0.264433              88         17          2       191                 4
# 0.264433              88         17          4       191                 4
# 0.264433              88         17          6       191                 4
# 0.264433              88         17          8       191                 4
# 0.264064              96         15          8       191                 3
# ...                  ...        ...        ...       ...               ...
# 0.253557              88         15          6       173                 6
# 0.253557              88         15          4       173                 6
# 0.253557              88         15          8       173                 6
# 0.253557              88         15          2       173                 6
# 0.253557              88         15         10       173                 6
#
#             train_score
# test_score
# 0.264433       0.348486
# 0.264433       0.348486
# 0.264433       0.348486
# 0.264433       0.348486
# 0.264064       0.355618
# ...                 ...
# 0.253557       0.332066
# 0.253557       0.332066
# 0.253557       0.332066
# 0.253557       0.332066
# 0.253557       0.332066
#
# [3125 rows x 6 columns]
#
# Top Best Parameters:
# best n_estimators: 88
# best max_depth: 17
# Best min_split: 2
# best max_leaf: 191
# best min_leaves: 4
#
#
# Best Random Forest Tuned Parameters Scores
# Test Accuracy: 0.6227692307692307
# balanced test score: 0.2644325729432112
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         7
#            4       0.00      0.00      0.00        48
#            5       0.66      0.70      0.68       528
#            6       0.59      0.77      0.67       705
#            7       0.67      0.34      0.45       282
#            8       1.00      0.04      0.07        54
#            9       0.00      0.00      0.00         1
#
#     accuracy                           0.62      1625
#    macro avg       0.42      0.26      0.27      1625
# weighted avg       0.62      0.62      0.59      1625
#
# Balanced Trained Score
# Model Name
# Tuned Random Forest    0.348486
# Name: Balanced Trained Score, dtype: float64
# Balanced Test Score
# Model Name
# Tuned Random Forest    0.264433
# Name: Balanced Test Score, dtype: float64
# updated comparison DataFrame
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             1.000000    0.672615             0.351007
# Gradient Boosting         0.713054    0.588923             0.269941
# Tuned Random Forest       0.760468    0.622769             0.264433
# Test Random Forest        0.763957    0.617846             0.261023
# ADA boost                 0.234606    0.227077             0.249291
# ADA Low Estimators        0.366174    0.344000             0.232777
# Logistic Regression       0.542693    0.540923             0.215561
# SVC poly                  0.580665    0.534769             0.206155
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.648993
# Gradient Boosting               0.430798
# Tuned Random Forest             0.084054
# Test Random Forest              0.109841
# ADA boost                      -0.048019
# ADA Low Estimators             -0.046457
# Logistic Regression             0.015383
# SVC poly                        0.086844
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Process Data for using in machine learning models

# %% [markdown]
# ### Bin into good and bad categories

# %%
# Check unique values of quality column
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3, 9], dtype=int64)

# %%
# Check how many of each value to pick where to create good/bad thresholds
df['quality'].value_counts(normalize=True)
# Out:
# quality
# 6    0.436509
# 5    0.329075
# 7    0.166077
# 4    0.033246
# 8    0.029706
# 3    0.004618
# 9    0.000770
# Name: proportion, dtype: float64

# %%
# Create threshold for bad category
threshold = 6
df['quality'] = df['quality'].where(df['quality'] > threshold, other=0)

# Check quality column for unique value changes
print(df['quality'].unique())
# Out:
# [0 7 8 9]

# %%
# Create threshold for good category
threshold = 7
df['quality'] = df['quality'].where(df['quality'] < threshold, other=1)

# Check quality column for unique value changes
print(df['quality'].unique())
# Out:
# [0 1]

# %%
# Check value percentages
df['quality'].value_counts(normalize=True)
# Out:
# quality
# 0    0.803448
# 1    0.196552
# Name: proportion, dtype: float64

# %% [markdown]
# ### Sample data to determine if sampling or binning is better

# %%
# Check quality column value percentages to determine sampling
df_sample['quality'].value_counts(normalize=True)
# Out:
# quality
# 6    0.436509
# 5    0.329075
# 7    0.166077
# 4    0.033246
# 8    0.029706
# 3    0.004618
# 9    0.000770
# Name: proportion, dtype: float64

# %%
# Check quality column values
df_sample['quality'].value_counts()
# Out:
# quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: count, dtype: int64

# %%
# Check quality column values mean
df_sample['quality'].value_counts().mean()
# Out:
# 928.1428571428571

# %%
# Set columns as variables for sampling
df_3 = df_sample[df_sample.quality==3]               
df_4 = df_sample[df_sample.quality==4]               
df_5 = df_sample[df_sample.quality==5]     
df_6 = df_sample[df_sample.quality==6]     
df_7 = df_sample[df_sample.quality==7]     
df_8 = df_sample[df_sample.quality==8]
df_9 = df_sample[df_sample.quality==9]

# %%
# Resample data to equalize values based on mean after removing outliers (n_samples chosen based on mean after removing outlier values)
df_3_ups = resample(df_3, replace=True, n_samples=1300) 
df_4_ups = resample(df_4, replace=True, n_samples=1300) 
df_7_ups = resample(df_7, replace=True, n_samples=1300) 
df_8_ups = resample(df_8, replace=True, n_samples=1300)
df_9_ups = resample(df_9, replace=True, n_samples=1300)

# Decreases the rows of Majority one's to make balance data
df_5_downs = df_5[df_5.quality==5].sample(n=1300).reset_index(drop=True)
df_6_downs = df_6[df_6.quality==6].sample(n=1300).reset_index(drop=True)

# %%
# Combine sampled columns into dataframe
sampled_q = pd.concat([df_3_ups, df_4_ups, df_7_ups, 
                        df_8_ups, df_9_ups, df_5_downs, df_6_downs]).reset_index(drop=True)

# Display new sampled dataframe
sampled_q
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               8.5             0.260         0.21            16.2      0.074
# 1              10.4             0.610         0.49             2.1      0.200
# 2               9.4             0.240         0.29             8.5      0.037
# 3               7.1             0.320         0.32            11.0      0.038
# 4               7.1             0.875         0.05             5.7      0.082
# ...             ...               ...          ...             ...        ...
# 9095            7.1             0.320         0.29             4.0      0.038
# 9096            7.0             0.340         0.26            10.3      0.041
# 9097            6.4             0.300         0.27             5.0      0.058
# 9098            7.2             0.200         0.30             2.0      0.039
# 9099            6.7             0.270         0.26             2.3      0.043
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    41.0                 197.0  0.99800  3.02       0.50
# 1                     5.0                  16.0  0.99940  3.16       0.63
# 2                   124.0                 208.0  0.99395  2.90       0.38
# 3                    16.0                  66.0  0.99370  3.24       0.40
# 4                     3.0                  14.0  0.99808  3.40       0.52
# ...                   ...                   ...      ...   ...        ...
# 9095                 33.0                 170.0  0.99463  3.27       0.64
# 9096                 51.0                 166.0  0.99382  3.08       0.35
# 9097                 27.0                 151.0  0.99198  3.22       0.49
# 9098                 43.0                 188.0  0.99110  3.30       0.41
# 9099                 61.0                 181.0  0.99394  3.45       0.63
#
#       alcohol  quality wine_type
# 0         9.8        3     white
# 1         8.4        3       red
# 2        11.0        3     white
# 3        11.5        3     white
# 4        10.2        3       red
# ...       ...      ...       ...
# 9095     10.2        6     white
# 9096     11.6        6     white
# 9097     12.2        6     white
# 9098     12.0        6     white
# 9099     10.6        6     white
#
# [9100 rows x 13 columns]

# %% [markdown]
# ## Check column importance to determine features to use

# %% [markdown]
# ### Create initial Random Forest Classifier model to determine feature importance to full dataset

# %%
# Create initial Random Forest Classifier Model to determine feature importance
rf_importance = RandomForestClassifier(random_state=13)

# Fit data to initial Random Forest Classifier Model
rf_importance.fit(X_train0, y_train0)
# Out:
# RandomForestClassifier(random_state=13)

# %%
# Make predictions to determine feature importance
y_train_pred = rf_importance.predict(X_train0)
y_test_pred = rf_importance.predict(X_test0)

# %%
# Create variables to store accuracy_scores and Balanced Accuracy Score
train_accuracy = accuracy_score(y_train0, y_train_pred)
test_accuracy = accuracy_score(y_test0, y_test_pred)
balanced_test = balanced_accuracy_score(y_test0, y_test_pred)

# Show results of initial Random Forest Classifier Model
print(f'\nRandom Forest \nTrain Accuracy: {train_accuracy}\nTest Accuracy: {test_accuracy}\nBalanced Test Score: {balanced_test}')
# Out:
# Random Forest
# Train Accuracy: 1.0
# Test Accuracy: 0.6726153846153846
# Balanced Test Score: 0.3510074145712444

# %% [markdown]
# ### Create feature_importance_ instance to View most important features

# %%
# Create variable to store most important features
importances = rf_importance.feature_importances_

# Sort most important features for better usage
importances_sorted = sorted(zip(importances, X0.columns), reverse=True)

# View most important features
print("Most Important Features:")

# Loop through to display features and importance percentage
for importance, feature in importances_sorted[:11]:
    print(f"{feature}: {importance:.4f}")
# Out:
# Most Important Features:
# alcohol: 0.1241
# density: 0.1041
# volatile acidity: 0.1005
# total sulfur dioxide: 0.0906
# chlorides: 0.0894
# sulphates: 0.0865
# residual sugar: 0.0854
# free sulfur dioxide: 0.0853
# pH: 0.0816
# citric acid: 0.0782
# fixed acidity: 0.0743

# %%
# Create variable to plot feature importance
feature_importance_df = pd.DataFrame(importances_sorted, columns=['Importance', 'Feature']).sort_values(by='Importance', ascending=False)

# Plot feature importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance')
plt.show()

# %% [markdown]
# ### Drop features based on importance

# %%
# Drop columns for sampled set based on feature importance (less than 8% was chosen by testing), and set as X and y variables for sample data
X = sampled_q.drop(columns=['quality','fixed acidity','citric acid','wine_type'])
y = sampled_q['quality']
X, y
# Out:
# (      volatile acidity  residual sugar  chlorides  free sulfur dioxide  \
#  0                0.260            16.2      0.074                 41.0
#  1                0.610             2.1      0.200                  5.0
#  2                0.240             8.5      0.037                124.0
#  3                0.320            11.0      0.038                 16.0
#  4                0.875             5.7      0.082                  3.0
#  ...                ...             ...        ...                  ...
#  9095             0.320             4.0      0.038                 33.0
#  9096             0.340            10.3      0.041                 51.0
#  9097             0.300             5.0      0.058                 27.0
#  9098             0.200             2.0      0.039                 43.0
#  9099             0.270             2.3      0.043                 61.0
#
#        total sulfur dioxide  density    pH  sulphates  alcohol
#  0                    197.0  0.99800  3.02       0.50      9.8
#  1                     16.0  0.99940  3.16       0.63      8.4
#  2                    208.0  0.99395  2.90       0.38     11.0
#  3                     66.0  0.99370  3.24       0.40     11.5
#  4                     14.0  0.99808  3.40       0.52     10.2
#  ...                    ...      ...   ...        ...      ...
#  9095                 170.0  0.99463  3.27       0.64     10.2
#  9096                 166.0  0.99382  3.08       0.35     11.6
#  9097                 151.0  0.99198  3.22       0.49     12.2
#  9098                 188.0  0.99110  3.30       0.41     12.0
#  9099                 181.0  0.99394  3.45       0.63     10.6
#
#  [9100 rows x 9 columns],
#  0       3
#  1       3
#  2       3
#  3       3
#  4       3
#         ..
#  9095    6
#  9096    6
#  9097    6
#  9098    6
#  9099    6
#  Name: quality, Length: 9100, dtype: int64)

# %%
# Drop columns for binned set based on feature importance and correlation, and set as X and y variables for bins models tests
X1 = df.drop(columns=['quality','fixed acidity','citric acid','wine_type'])
y1 = df['quality']
X1, y1
# Out:
# (      volatile acidity  residual sugar  chlorides  free sulfur dioxide  \
#  0                 0.70             1.9      0.076                 11.0
#  1                 0.88             2.6      0.098                 25.0
#  2                 0.76             2.3      0.092                 15.0
#  3                 0.28             1.9      0.075                 17.0
#  4                 0.70             1.9      0.076                 11.0
#  ...                ...             ...        ...                  ...
#  4893              0.21             1.6      0.039                 24.0
#  4894              0.32             8.0      0.047                 57.0
#  4895              0.24             1.2      0.041                 30.0
#  4896              0.29             1.1      0.022                 20.0
#  4897              0.21             0.8      0.020                 22.0
#
#        total sulfur dioxide  density    pH  sulphates  alcohol
#  0                     34.0  0.99780  3.51       0.56      9.4
#  1                     67.0  0.99680  3.20       0.68      9.8
#  2                     54.0  0.99700  3.26       0.65      9.8
#  3                     60.0  0.99800  3.16       0.58      9.8
#  4                     34.0  0.99780  3.51       0.56      9.4
#  ...                    ...      ...   ...        ...      ...
#  4893                  92.0  0.99114  3.27       0.50     11.2
#  4894                 168.0  0.99490  3.15       0.46      9.6
#  4895                 111.0  0.99254  2.99       0.46      9.4
#  4896                 110.0  0.98869  3.34       0.38     12.8
#  4897                  98.0  0.98941  3.26       0.32     11.8
#
#  [6497 rows x 9 columns],
#  0       0
#  1       0
#  2       0
#  3       0
#  4       0
#         ..
#  4893    0
#  4894    0
#  4895    0
#  4896    1
#  4897    0
#  Name: quality, Length: 6497, dtype: int64)

# %% [markdown]
# ## Use processed data to determine best scores
# ### split data into training and test variables

# %%
# Split dropped column data into training and testing data for sampled data tests
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=13)

# %%
# Split dropped column data into training and testing data for bins models tests
X_train1,X_test1,y_train1,y_test1 = train_test_split(X1,y1,random_state=13)

# %% [markdown]
# ### Run bin data through models

# %%
# Run data through many_models_full function to determine scores and optimize Random Forest Classifier Model
print('Binned Data results full')
models_full_bin = tests.many_models_full(X_train1,y_train1,X_test1,y_test1)
# Out:
# Binned Data results full
#
# Random Forest
# Test Accuracy: 0.8769230769230769
# balanced test score: 0.7383194795141641
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      1288
#            1       0.84      0.50      0.63       337
#
#     accuracy                           0.88      1625
#    macro avg       0.86      0.74      0.78      1625
# weighted avg       0.87      0.88      0.86      1625
#
#
# Gradient Boost
# Test Accuracy: 0.827076923076923
# balanced test score: 0.6444329763901432
#
#  classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90      1288
#            1       0.67      0.33      0.44       337
#
#     accuracy                           0.83      1625
#    macro avg       0.76      0.64      0.67      1625
# weighted avg       0.81      0.83      0.80      1625
#
#
# Logistic Regression
# Test Accuracy: 0.8104615384615385
# balanced test score: 0.5978007446043828
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      1288
#            1       0.61      0.23      0.34       337
#
#     accuracy                           0.81      1625
#    macro avg       0.72      0.60      0.61      1625
# weighted avg       0.78      0.81      0.78      1625
#
#
# Poly Support Vector
# Test Accuracy: 0.811076923076923
# Balanced test score: 0.5664200011058481
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.98      0.89      1288
#            1       0.71      0.15      0.25       337
#
#     accuracy                           0.81      1625
#    macro avg       0.76      0.57      0.57      1625
# weighted avg       0.79      0.81      0.76      1625
#
#
# ADA low estimators
# Test Accuracy: 0.8098461538461539
# balanced test score: 0.6094628342886632
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.95      0.89      1288
#            1       0.59      0.27      0.37       337
#
#     accuracy                           0.81      1625
#    macro avg       0.71      0.61      0.63      1625
# weighted avg       0.78      0.81      0.78      1625
#
#
# ADA
# Test Accuracy: 0.8104615384615385
# balanced test score: 0.6262832445583059
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89      1288
#            1       0.58      0.31      0.41       337
#
#     accuracy                           0.81      1625
#    macro avg       0.71      0.63      0.65      1625
# weighted avg       0.79      0.81      0.79      1625
#
#
# SVC Sigmoid
# Test Accuracy: 0.7304615384615385
# balanced test score: 0.5714354829791548
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      1288
#            1       0.33      0.30      0.32       337
#
#     accuracy                           0.73      1625
#    macro avg       0.58      0.57      0.57      1625
# weighted avg       0.72      0.73      0.73      1625
#
# non-tuned models dataframe
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             1.000000    0.876923             0.738319
# Gradient Boosting         0.873358    0.827077             0.644433
# ADA boost                 0.832307    0.810462             0.626283
# ADA Low Estimators        0.818966    0.809846             0.609463
# Logistic Regression       0.821223    0.810462             0.597801
# SVC sigmoid               0.739122    0.730462             0.571435
# SVC poly                  0.831897    0.811077             0.566420
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.261681
# Gradient Boosting               0.071898
# ADA boost                       0.023331
# ADA Low Estimators              0.007196
# Logistic Regression             0.005686
# SVC sigmoid                     0.000614
# SVC poly                        0.023846
#
# Random Forest Parameter Tuning:
#
# best depth balanced test score:
#     train_score  test_score  max_depth
# 15     0.999873    0.750258         16
# 17     1.000000    0.747679         18
# 14     0.999873    0.745738         15
# 18     1.000000    0.744961         19
# 16     0.999873    0.743866         17
# max depths:
# [16, 18, 15, 19, 17]
#
# best min leaf balanced test score:
#    train_score  test_score  min_leaf
# 0     0.964766    0.736517         2
# 1     0.920537    0.711225         3
# 2     0.882794    0.701616         4
# 3     0.856777    0.699744         5
# 4     0.835928    0.689746         6
# best min leaf
# [2, 3, 4, 5, 6]
#
# best n_estimators balanced test score:
#     train_score  test_score  n_estimators
# 48     0.965298    0.735421            98
# 37     0.963853    0.735033            76
# 38     0.963448    0.734714            78
# 45     0.964107    0.734326            92
# 43     0.965830    0.733938            88
# best n_estimators
# [98, 76, 78, 92, 88]
#
# best min_split balanced test score:
#    train_score  test_score  min_split
# 0     0.965298    0.735421          2
# 1     0.965298    0.735421          4
# 2     0.943791    0.724259          6
# 3     0.919855    0.720127          8
# 4     0.905921    0.717867         10
# best min_split
# [2, 4, 6, 8, 10]
#
# best max_leaf balanced test score:
#     train_score  test_score  max_leaf
# 64     0.876793    0.706067       194
# 65     0.877984    0.705679       197
# 63     0.875729    0.705290       191
# 62     0.872665    0.698967       188
# 59     0.864582    0.698191       179
# best max leaf
# [194, 197, 191, 188, 179]
#
#
# Test best Random Forest Tuned Parameters scores
#
#
# Test Best Random Forest Tuned Parameters Scores
# Test Accuracy: 0.864
# balanced test score: 0.7060667287170319
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      1288
#            1       0.83      0.44      0.57       337
#
#     accuracy                           0.86      1625
#    macro avg       0.85      0.71      0.75      1625
# weighted avg       0.86      0.86      0.85      1625
#
# updated comparison DataFrame
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             1.000000    0.876923             0.738319
# Test Random Forest        0.950739    0.864000             0.706067
# Gradient Boosting         0.873358    0.827077             0.644433
# ADA boost                 0.832307    0.810462             0.626283
# ADA Low Estimators        0.818966    0.809846             0.609463
# Logistic Regression       0.821223    0.810462             0.597801
# SVC sigmoid               0.739122    0.730462             0.571435
# SVC poly                  0.831897    0.811077             0.566420
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.261681
# Test Random Forest              0.170726
# Gradient Boosting               0.071898
# ADA boost                       0.023331
# ADA Low Estimators              0.007196
# Logistic Regression             0.005686
# SVC sigmoid                     0.000614
# SVC poly                        0.023846
#
# best results:
#             n_estimators  max_depth  min_split  max_leaf  min_samples_leaf  \
# test_score
# 0.711225              98         17          8       191                 2
# 0.710518              98         17          6       197                 2
# 0.710449              98         15          4       197                 2
# 0.710449              98         15          2       197                 2
# 0.709353              76         16          2       191                 2
# ...                  ...        ...        ...       ...               ...
# 0.682259              78         17          4       179                 3
# 0.682259              78         17          2       179                 3
# 0.680775              88         15          4       179                 3
# 0.680775              88         15          6       179                 3
# 0.680775              88         15          2       179                 3
#
#             train_score
# test_score
# 0.711225       0.878261
# 0.710518       0.874387
# 0.710449       0.873728
# 0.710449       0.873728
# 0.709353       0.871346
# ...                 ...
# 0.682259       0.861263
# 0.682259       0.861263
# 0.680775       0.860604
# 0.680775       0.860604
# 0.680775       0.860604
#
# [3125 rows x 6 columns]
#
# Top Best Parameters:
# best n_estimators: 98
# best max_depth: 17
# Best min_split: 8
# best max_leaf: 191
# best min_leaves: 2
#
#
# Best Random Forest Tuned Parameters Scores
# Test Accuracy: 0.8652307692307692
# balanced test score: 0.7112250493023942
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1288
#            1       0.82      0.45      0.58       337
#
#     accuracy                           0.87      1625
#    macro avg       0.85      0.71      0.75      1625
# weighted avg       0.86      0.87      0.85      1625
#
# Balanced Trained Score
# Model Name
# Tuned Random Forest    0.878261
# Name: Balanced Trained Score, dtype: float64
# Balanced Test Score
# Model Name
# Tuned Random Forest    0.711225
# Name: Balanced Test Score, dtype: float64
# updated comparison DataFrame
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             1.000000    0.876923             0.738319
# Tuned Random Forest       0.951149    0.865231             0.711225
# Test Random Forest        0.950739    0.864000             0.706067
# Gradient Boosting         0.873358    0.827077             0.644433
# ADA boost                 0.832307    0.810462             0.626283
# ADA Low Estimators        0.818966    0.809846             0.609463
# Logistic Regression       0.821223    0.810462             0.597801
# SVC sigmoid               0.739122    0.730462             0.571435
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.261681
# Tuned Random Forest             0.167036
# Test Random Forest              0.170726
# Gradient Boosting               0.071898
# ADA boost                       0.023331
# ADA Low Estimators              0.007196
# Logistic Regression             0.005686
# SVC sigmoid                     0.000614

# %% [markdown]
# ### Run sampled data through models

# %%
# Run sampled data through many_models_full function to determine scores and optimize Random Forest Classifier Model
print('Sampled Data results Full')
models_full_sample = tests.many_models_full(X_train,y_train,X_test,y_test)
# Out:
# Sampled Data results Full
#
# Random Forest
# Test Accuracy: 0.8632967032967033
# balanced test score: 0.8583603522322016
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.99      1.00      1.00       324
#            4       0.92      0.99      0.95       334
#            5       0.73      0.72      0.72       314
#            6       0.59      0.48      0.53       306
#            7       0.78      0.83      0.81       334
#            8       0.95      0.99      0.97       331
#            9       1.00      1.00      1.00       332
#
#     accuracy                           0.86      2275
#    macro avg       0.85      0.86      0.85      2275
# weighted avg       0.86      0.86      0.86      2275
#
#
# Gradient Boost
# Test Accuracy: 0.7674725274725275
# balanced test score: 0.76256458629487
#
#  classification report:
#                precision    recall  f1-score   support
#
#            3       0.97      1.00      0.98       324
#            4       0.81      0.78      0.79       334
#            5       0.59      0.61      0.60       314
#            6       0.47      0.35      0.40       306
#            7       0.66      0.67      0.66       334
#            8       0.78      0.92      0.85       331
#            9       1.00      1.00      1.00       332
#
#     accuracy                           0.77      2275
#    macro avg       0.75      0.76      0.76      2275
# weighted avg       0.76      0.77      0.76      2275
#
#
# Logistic Regression
# Test Accuracy: 0.458021978021978
# balanced test score: 0.45488370915539006
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.46      0.45      0.45       324
#            4       0.52      0.49      0.51       334
#            5       0.41      0.37      0.39       314
#            6       0.26      0.23      0.24       306
#            7       0.37      0.24      0.29       334
#            8       0.38      0.40      0.39       331
#            9       0.64      1.00      0.78       332
#
#     accuracy                           0.46      2275
#    macro avg       0.43      0.45      0.44      2275
# weighted avg       0.44      0.46      0.44      2275
#
#
# Poly Support Vector
# Test Accuracy: 0.6013186813186813
# Balanced test score: 0.5993960003078767
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.88      0.84      0.86       324
#            4       0.67      0.57      0.62       334
#            5       0.53      0.48      0.51       314
#            6       0.28      0.42      0.33       306
#            7       0.45      0.35      0.40       334
#            8       0.58      0.52      0.55       331
#            9       0.90      1.00      0.95       332
#
#     accuracy                           0.60      2275
#    macro avg       0.61      0.60      0.60      2275
# weighted avg       0.62      0.60      0.60      2275
#
#
# ADA low estimators
# Test Accuracy: 0.3468131868131868
# balanced test score: 0.34346407531932066
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.29      0.51      0.37       324
#            4       0.15      0.30      0.20       334
#            5       0.28      0.27      0.28       314
#            6       0.37      0.04      0.08       306
#            7       0.35      0.18      0.24       334
#            8       0.41      0.10      0.16       331
#            9       0.76      1.00      0.86       332
#
#     accuracy                           0.35      2275
#    macro avg       0.37      0.34      0.31      2275
# weighted avg       0.37      0.35      0.31      2275
#
#
# ADA
# Test Accuracy: 0.3468131868131868
# balanced test score: 0.34346407531932066
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.29      0.51      0.37       324
#            4       0.15      0.30      0.20       334
#            5       0.28      0.27      0.28       314
#            6       0.37      0.04      0.08       306
#            7       0.35      0.18      0.24       334
#            8       0.41      0.10      0.16       331
#            9       0.76      1.00      0.86       332
#
#     accuracy                           0.35      2275
#    macro avg       0.37      0.34      0.31      2275
# weighted avg       0.37      0.35      0.31      2275
#
#
# SVC Sigmoid
# Test Accuracy: 0.21054945054945054
# balanced test score: 0.20870080135950525
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.10      0.27      0.15       324
#            4       0.26      0.22      0.24       334
#            5       0.33      0.11      0.17       314
#            6       0.23      0.10      0.14       306
#            7       0.16      0.22      0.18       334
#            8       0.33      0.14      0.20       331
#            9       0.45      0.40      0.42       332
#
#     accuracy                           0.21      2275
#    macro avg       0.26      0.21      0.21      2275
# weighted avg       0.27      0.21      0.22      2275
#
# non-tuned models dataframe
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             1.000000    0.863297             0.858360
# Gradient Boosting         0.836923    0.767473             0.762565
# SVC poly                  0.630476    0.601319             0.599396
# Logistic Regression       0.454652    0.458022             0.454884
# ADA Low Estimators        0.333187    0.346813             0.343464
# ADA boost                 0.333187    0.346813             0.343464
# SVC sigmoid               0.201758    0.210549             0.208701
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.141640
# Gradient Boosting               0.075547
# SVC poly                        0.031632
# Logistic Regression             0.000716
# ADA Low Estimators             -0.009063
# ADA boost                      -0.009063
# SVC sigmoid                    -0.006262
#
# Random Forest Parameter Tuning:
#
# best depth balanced test score:
#     train_score  test_score  max_depth
# 16     0.997401    0.855261         17
# 18     0.999277    0.853456         19
# 17     0.998407    0.851601         18
# 15     0.993356    0.850275         16
# 14     0.987279    0.845869         15
# max depths:
# [17, 19, 18, 16, 15]
#
# best min leaf balanced test score:
#    train_score  test_score  min_leaf
# 0     0.987098    0.849623         2
# 1     0.971912    0.833284         3
# 2     0.956397    0.830787         4
# 3     0.940786    0.820384         5
# 4     0.924659    0.809955         6
# best min leaf
# [2, 3, 4, 5, 6]
#
# best n_estimators balanced test score:
#     train_score  test_score  n_estimators
# 48     0.987102    0.850090            98
# 35     0.987400    0.849043            72
# 36     0.986661    0.848238            74
# 47     0.986958    0.848235            96
# 42     0.988110    0.848184            86
# best n_estimators
# [98, 72, 74, 96, 86]
#
# best min_split balanced test score:
#    train_score  test_score  min_split
# 0     0.987102    0.850090          2
# 1     0.987102    0.850090          4
# 2     0.981022    0.839204          6
# 3     0.974511    0.838453          8
# 4     0.966862    0.838352         10
# best min_split
# [2, 4, 6, 8, 10]
#
# best max_leaf balanced test score:
#     train_score  test_score  max_leaf
# 65     0.881445    0.799351       197
# 64     0.879118    0.796652       194
# 63     0.877516    0.795345       191
# 62     0.875769    0.792622       188
# 60     0.875926    0.792622       182
# best max leaf
# [197, 194, 191, 188, 182]
#
#
# Test best Random Forest Tuned Parameters scores
#
#
# Test Best Random Forest Tuned Parameters Scores
# Test Accuracy: 0.8052747252747253
# balanced test score: 0.7993505578919929
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.98      1.00      0.99       324
#            4       0.82      0.93      0.87       334
#            5       0.68      0.63      0.66       314
#            6       0.47      0.33      0.39       306
#            7       0.71      0.74      0.72       334
#            8       0.85      0.96      0.90       331
#            9       1.00      1.00      1.00       332
#
#     accuracy                           0.81      2275
#    macro avg       0.79      0.80      0.79      2275
# weighted avg       0.79      0.81      0.79      2275
#
# updated comparison DataFrame
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             1.000000    0.863297             0.858360
# Test Random Forest        0.880147    0.805275             0.799351
# Gradient Boosting         0.836923    0.767473             0.762565
# SVC poly                  0.630476    0.601319             0.599396
# Logistic Regression       0.454652    0.458022             0.454884
# ADA Low Estimators        0.333187    0.346813             0.343464
# ADA boost                 0.333187    0.346813             0.343464
# SVC sigmoid               0.201758    0.210549             0.208701
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.141640
# Test Random Forest              0.082094
# Gradient Boosting               0.075547
# SVC poly                        0.031632
# Logistic Regression             0.000716
# ADA Low Estimators             -0.009063
# ADA boost                      -0.009063
# SVC sigmoid                    -0.006262
#
# best results:
#             n_estimators  max_depth  min_split  max_leaf  min_samples_leaf  \
# test_score
# 0.804102              72         16          6       197                 2
# 0.804000              86         16         10       197                 3
# 0.803933              98         19          8       197                 2
# 0.803842              98         19          8       194                 2
# 0.803760              86         19          8       197                 2
# ...                  ...        ...        ...       ...               ...
# 0.779234              96         16         10       182                 6
# 0.779234              96         16          6       182                 6
# 0.779234              96         16          4       182                 6
# 0.779234              96         16          2       182                 6
# 0.779234              96         16          8       182                 6
#
#             train_score
# test_score
# 0.804102       0.883048
# 0.804000       0.883757
# 0.803933       0.880154
# 0.803842       0.879140
# 0.803760       0.882624
# ...                 ...
# 0.779234       0.868626
# 0.779234       0.868626
# 0.779234       0.868626
# 0.779234       0.868626
# 0.779234       0.868626
#
# [3125 rows x 6 columns]
#
# Top Best Parameters:
# best n_estimators: 72
# best max_depth: 16
# Best min_split: 6
# best max_leaf: 197
# best min_leaves: 2
#
#
# Best Random Forest Tuned Parameters Scores
# Test Accuracy: 0.8101098901098901
# balanced test score: 0.8041023244258644
# classification report:
#                precision    recall  f1-score   support
#
#            3       0.99      1.00      0.99       324
#            4       0.82      0.93      0.87       334
#            5       0.67      0.63      0.65       314
#            6       0.49      0.34      0.40       306
#            7       0.71      0.77      0.74       334
#            8       0.86      0.96      0.91       331
#            9       1.00      1.00      1.00       332
#
#     accuracy                           0.81      2275
#    macro avg       0.79      0.80      0.79      2275
# weighted avg       0.80      0.81      0.80      2275
#
# Balanced Trained Score
# Model Name
# Tuned Random Forest    0.883048
# Name: Balanced Trained Score, dtype: float64
# Balanced Test Score
# Model Name
# Tuned Random Forest    0.804102
# Name: Balanced Test Score, dtype: float64
# updated comparison DataFrame
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             1.000000    0.863297             0.858360
# Tuned Random Forest       0.881758    0.810110             0.804102
# Test Random Forest        0.880147    0.805275             0.799351
# Gradient Boosting         0.836923    0.767473             0.762565
# SVC poly                  0.630476    0.601319             0.599396
# Logistic Regression       0.454652    0.458022             0.454884
# ADA Low Estimators        0.333187    0.346813             0.343464
# ADA boost                 0.333187    0.346813             0.343464
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.141640
# Tuned Random Forest             0.078946
# Test Random Forest              0.082094
# Gradient Boosting               0.075547
# SVC poly                        0.031632
# Logistic Regression             0.000716
# ADA Low Estimators             -0.009063
# ADA boost                      -0.009063

# %% [markdown]
# ## Test sampled data combined with binned data through models to determine good/bad wines

# %% [markdown]
# ### Combine sampled data into bins

# %%
# Create a new dataframe for the combined processing data
combined_df = sampled_q.copy()
# View dataframe
combined_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               8.5             0.260         0.21            16.2      0.074
# 1              10.4             0.610         0.49             2.1      0.200
# 2               9.4             0.240         0.29             8.5      0.037
# 3               7.1             0.320         0.32            11.0      0.038
# 4               7.1             0.875         0.05             5.7      0.082
# ...             ...               ...          ...             ...        ...
# 9095            7.1             0.320         0.29             4.0      0.038
# 9096            7.0             0.340         0.26            10.3      0.041
# 9097            6.4             0.300         0.27             5.0      0.058
# 9098            7.2             0.200         0.30             2.0      0.039
# 9099            6.7             0.270         0.26             2.3      0.043
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    41.0                 197.0  0.99800  3.02       0.50
# 1                     5.0                  16.0  0.99940  3.16       0.63
# 2                   124.0                 208.0  0.99395  2.90       0.38
# 3                    16.0                  66.0  0.99370  3.24       0.40
# 4                     3.0                  14.0  0.99808  3.40       0.52
# ...                   ...                   ...      ...   ...        ...
# 9095                 33.0                 170.0  0.99463  3.27       0.64
# 9096                 51.0                 166.0  0.99382  3.08       0.35
# 9097                 27.0                 151.0  0.99198  3.22       0.49
# 9098                 43.0                 188.0  0.99110  3.30       0.41
# 9099                 61.0                 181.0  0.99394  3.45       0.63
#
#       alcohol  quality wine_type
# 0         9.8        3     white
# 1         8.4        3       red
# 2        11.0        3     white
# 3        11.5        3     white
# 4        10.2        3       red
# ...       ...      ...       ...
# 9095     10.2        6     white
# 9096     11.6        6     white
# 9097     12.2        6     white
# 9098     12.0        6     white
# 9099     10.6        6     white
#
# [9100 rows x 13 columns]

# %%
combined_df['quality'].value_counts()
# Out:
# quality
# 3    1300
# 4    1300
# 7    1300
# 8    1300
# 9    1300
# 5    1300
# 6    1300
# Name: count, dtype: int64

# %%
# Create threshold for bad category
threshold = 6
combined_df['quality'] = combined_df['quality'].where(combined_df['quality'] > threshold, other=0)

# Check quality column for unique value changes
print(combined_df['quality'].unique())
# Out:
# [0 7 8 9]

# %%
# Create threshold for good category
threshold = 7
combined_df['quality'] = combined_df['quality'].where(combined_df['quality'] < threshold, other=1)

# Check quality column for unique value changes
print(combined_df['quality'].unique())
print(combined_df['quality'].value_counts())
# Out:
# [0 1]
# quality
# 0    5200
# 1    3900
# Name: count, dtype: int64

# %%
# View updated combined Dataframe
combined_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               8.5             0.260         0.21            16.2      0.074
# 1              10.4             0.610         0.49             2.1      0.200
# 2               9.4             0.240         0.29             8.5      0.037
# 3               7.1             0.320         0.32            11.0      0.038
# 4               7.1             0.875         0.05             5.7      0.082
# ...             ...               ...          ...             ...        ...
# 9095            7.1             0.320         0.29             4.0      0.038
# 9096            7.0             0.340         0.26            10.3      0.041
# 9097            6.4             0.300         0.27             5.0      0.058
# 9098            7.2             0.200         0.30             2.0      0.039
# 9099            6.7             0.270         0.26             2.3      0.043
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    41.0                 197.0  0.99800  3.02       0.50
# 1                     5.0                  16.0  0.99940  3.16       0.63
# 2                   124.0                 208.0  0.99395  2.90       0.38
# 3                    16.0                  66.0  0.99370  3.24       0.40
# 4                     3.0                  14.0  0.99808  3.40       0.52
# ...                   ...                   ...      ...   ...        ...
# 9095                 33.0                 170.0  0.99463  3.27       0.64
# 9096                 51.0                 166.0  0.99382  3.08       0.35
# 9097                 27.0                 151.0  0.99198  3.22       0.49
# 9098                 43.0                 188.0  0.99110  3.30       0.41
# 9099                 61.0                 181.0  0.99394  3.45       0.63
#
#       alcohol  quality wine_type
# 0         9.8        0     white
# 1         8.4        0       red
# 2        11.0        0     white
# 3        11.5        0     white
# 4        10.2        0       red
# ...       ...      ...       ...
# 9095     10.2        0     white
# 9096     11.6        0     white
# 9097     12.2        0     white
# 9098     12.0        0     white
# 9099     10.6        0     white
#
# [9100 rows x 13 columns]

# %% [markdown]
# ### split combined data into training and testing data

# %%
# Set X and y variables
X2 = combined_df.drop(['quality','fixed acidity','citric acid','wine_type'],axis=1)
y2 = combined_df['quality']

# %%
# Split into training and testing data
X_train2,X_test2,y_train2,y_test2 = train_test_split(X2,y2,random_state=13)

# %% [markdown]
# ### Run combined sampled and binned data through models

# %%
# Run combined data through many_models_full function to determine if all parameter settings are worth extra time.
# score and optimize Random Forest Classifier Model
print('Combined Data results full leaf')
models_full_combined = tests.many_models_full(X_train2,y_train2,X_test2,y_test2)
# Out:
# Combined Data results full leaf
#
# Random Forest
# Test Accuracy: 0.9424175824175824
# balanced test score: 0.9422422196165963
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95      1278
#            1       0.93      0.94      0.93       997
#
#     accuracy                           0.94      2275
#    macro avg       0.94      0.94      0.94      2275
# weighted avg       0.94      0.94      0.94      2275
#
#
# Gradient Boost
# Test Accuracy: 0.8918681318681319
# balanced test score: 0.8911852929681061
#
#  classification report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.90      0.90      1278
#            1       0.87      0.89      0.88       997
#
#     accuracy                           0.89      2275
#    macro avg       0.89      0.89      0.89      2275
# weighted avg       0.89      0.89      0.89      2275
#
#
# Logistic Regression
# Test Accuracy: 0.8180219780219781
# balanced test score: 0.8176285507539833
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84      1278
#            1       0.78      0.81      0.80       997
#
#     accuracy                           0.82      2275
#    macro avg       0.82      0.82      0.82      2275
# weighted avg       0.82      0.82      0.82      2275
#
#
# Poly Support Vector
# Test Accuracy: 0.8479120879120879
# Balanced test score: 0.8414759144412894
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.89      0.87      1278
#            1       0.85      0.79      0.82       997
#
#     accuracy                           0.85      2275
#    macro avg       0.85      0.84      0.84      2275
# weighted avg       0.85      0.85      0.85      2275
#
#
# ADA low estimators
# Test Accuracy: 0.8272527472527472
# balanced test score: 0.8216543213364663
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85      1278
#            1       0.82      0.78      0.80       997
#
#     accuracy                           0.83      2275
#    macro avg       0.83      0.82      0.82      2275
# weighted avg       0.83      0.83      0.83      2275
#
#
# ADA
# Test Accuracy: 0.8597802197802198
# balanced test score: 0.8558986819613771
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88      1278
#            1       0.85      0.82      0.84       997
#
#     accuracy                           0.86      2275
#    macro avg       0.86      0.86      0.86      2275
# weighted avg       0.86      0.86      0.86      2275
#
#
# SVC Sigmoid
# Test Accuracy: 0.6967032967032967
# balanced test score: 0.6905709303183416
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.74      0.73      1278
#            1       0.66      0.64      0.65       997
#
#     accuracy                           0.70      2275
#    macro avg       0.69      0.69      0.69      2275
# weighted avg       0.70      0.70      0.70      2275
#
# non-tuned models dataframe
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             1.000000    0.942418             0.942242
# Gradient Boosting         0.909304    0.891868             0.891185
# ADA boost                 0.869597    0.859780             0.855899
# SVC poly                  0.860366    0.847912             0.841476
# ADA Low Estimators        0.839267    0.827253             0.821654
# Logistic Regression       0.813480    0.818022             0.817629
# SVC sigmoid               0.704615    0.696703             0.690571
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.057758
# Gradient Boosting               0.016923
# ADA boost                       0.008980
# SVC poly                        0.011299
# ADA Low Estimators              0.011196
# Logistic Regression            -0.005425
# SVC sigmoid                     0.007086
#
# Random Forest Parameter Tuning:
#
# best depth balanced test score:
#     train_score  test_score  max_depth
# 17     1.000000    0.941399         18
# 15     1.000000    0.941289         16
# 13     0.998718    0.941229         14
# 18     1.000000    0.940396         19
# 16     1.000000    0.940396         17
# max depths:
# [18, 16, 14, 19, 17]
#
# best min leaf balanced test score:
#    train_score  test_score  min_leaf
# 0     0.995325    0.933535         2
# 1     0.987794    0.928510         3
# 2     0.982361    0.927396         4
# 3     0.971616    0.923043         5
# 4     0.964798    0.920255         6
# best min leaf
# [2, 3, 4, 5, 6]
#
# best n_estimators balanced test score:
#     train_score  test_score  n_estimators
# 16     0.994726    0.935150            34
# 43     0.995198    0.935150            88
# 39     0.995198    0.934257            80
# 40     0.995025    0.934257            82
# 22     0.994299    0.934037            46
# best n_estimators
# [34, 88, 80, 82, 46]
#
# best min_split balanced test score:
#    train_score  test_score  min_split
# 2     0.991429    0.935883          6
# 0     0.994726    0.935150          2
# 1     0.994726    0.935150          4
# 3     0.987067    0.931359          8
# 6     0.979026    0.929904         14
# best min_split
# [6, 2, 4, 8, 14]
#
# best max_leaf balanced test score:
#     train_score  test_score  max_leaf
# 60     0.974575    0.928460       182
# 64     0.975423    0.928069       194
# 62     0.975040    0.928069       188
# 61     0.974830    0.928069       185
# 59     0.973759    0.928069       179
# best max leaf
# [182, 194, 188, 185, 179]
#
#
# Test best Random Forest Tuned Parameters scores
#
#
# Test Best Random Forest Tuned Parameters Scores
# Test Accuracy: 0.9287912087912088
# balanced test score: 0.9284598710058187
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94      1278
#            1       0.91      0.93      0.92       997
#
#     accuracy                           0.93      2275
#    macro avg       0.93      0.93      0.93      2275
# weighted avg       0.93      0.93      0.93      2275
#
# updated comparison DataFrame
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             1.000000    0.942418             0.942242
# Test Random Forest        0.974945    0.928791             0.928460
# Gradient Boosting         0.909304    0.891868             0.891185
# ADA boost                 0.869597    0.859780             0.855899
# SVC poly                  0.860366    0.847912             0.841476
# ADA Low Estimators        0.839267    0.827253             0.821654
# Logistic Regression       0.813480    0.818022             0.817629
# SVC sigmoid               0.704615    0.696703             0.690571
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.057758
# Test Random Forest              0.046115
# Gradient Boosting               0.016923
# ADA boost                       0.008980
# SVC poly                        0.011299
# ADA Low Estimators              0.011196
# Logistic Regression            -0.005425
# SVC sigmoid                     0.007086
#
# best results:
#             n_estimators  max_depth  min_split  max_leaf  min_samples_leaf  \
# test_score
# 0.931579              46         16         14       182                 2
# 0.931579              46         16         14       194                 2
# 0.931579              46         16         14       188                 2
# 0.931579              46         16         14       185                 2
# 0.931359              46         18         14       185                 2
# ...                  ...        ...        ...       ...               ...
# 0.918028              46         18          4       179                 5
# 0.918028              46         18          8       182                 5
# 0.918028              46         19          2       179                 5
# 0.917747              34         18         14       179                 5
# 0.917747              34         19         14       179                 5
#
#             train_score
# test_score
# 0.931579       0.971106
# 0.931579       0.974613
# 0.931579       0.971960
# 0.931579       0.971361
# 0.931359       0.972560
# ...                 ...
# 0.918028       0.968963
# 0.918028       0.968836
# 0.918028       0.968319
# 0.917747       0.962976
# 0.917747       0.963103
#
# [3125 rows x 6 columns]
#
# Top Best Parameters:
# best n_estimators: 46
# best max_depth: 16
# Best min_split: 14
# best max_leaf: 182
# best min_leaves: 2
#
#
# Best Random Forest Tuned Parameters Scores
# Test Accuracy: 0.9314285714285714
# balanced test score: 0.9315791662938737
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      1278
#            1       0.91      0.93      0.92       997
#
#     accuracy                           0.93      2275
#    macro avg       0.93      0.93      0.93      2275
# weighted avg       0.93      0.93      0.93      2275
#
# Balanced Trained Score
# Model Name
# Tuned Random Forest    0.971106
# Name: Balanced Trained Score, dtype: float64
# Balanced Test Score
# Model Name
# Tuned Random Forest    0.931579
# Name: Balanced Test Score, dtype: float64
# updated comparison DataFrame
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             1.000000    0.942418             0.942242
# Tuned Random Forest       0.971575    0.931429             0.931579
# Test Random Forest        0.974945    0.928791             0.928460
# Gradient Boosting         0.909304    0.891868             0.891185
# ADA boost                 0.869597    0.859780             0.855899
# SVC poly                  0.860366    0.847912             0.841476
# ADA Low Estimators        0.839267    0.827253             0.821654
# Logistic Regression       0.813480    0.818022             0.817629
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.057758
# Tuned Random Forest             0.039527
# Test Random Forest              0.046115
# Gradient Boosting               0.016923
# ADA boost                       0.008980
# SVC poly                        0.011299
# ADA Low Estimators              0.011196
# Logistic Regression            -0.005425

# %%
# Run combined data through many_models_no_leaf function to determine if 'no min/max leaf' parameter setting is worth extra time.
# score and optimize Random Forest Classifier Model
print('Combined Data results no min/max leaf')
models_no_leaf_sample = tests.many_models_no_leaf(X_train2,y_train2,X_test2,y_test2)
# Out:
# Combined Data results no min/max leaf
#
# Random Forest
# Test Accuracy: 0.9424175824175824
# balanced test score: 0.9422422196165963
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95      1278
#            1       0.93      0.94      0.93       997
#
#     accuracy                           0.94      2275
#    macro avg       0.94      0.94      0.94      2275
# weighted avg       0.94      0.94      0.94      2275
#
#                Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest            1.0    0.942418             0.942242
#
#                Balanced Difference
# Model Name
# Random Forest             0.057758
#
# Random Forest Parameter Tuning:
#
# best depth balanced test score:
#     train_score  test_score  max_depth
# 17     1.000000    0.941399         18
# 15     1.000000    0.941289         16
# 13     0.998718    0.941229         14
# 18     1.000000    0.940396         19
# 16     1.000000    0.940396         17
# max depths:
# [18, 16, 14, 19, 17]
#
#
# best n_estimators balanced test score:
#     train_score  test_score  n_estimators
# 31     1.000000    0.943686            64
# 25     0.999828    0.942904            52
# 23     0.999828    0.942904            48
# 30     1.000000    0.942794            62
# 22     0.999828    0.942623            46
# best n_estimators
# [64, 52, 48, 62, 46]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 4
#       1 # Run combined data through many_models_no_leaf function to determine if 'no min/max leaf' parameter setting is worth extra time.
#       2 # score and optimize Random Forest Classifier Model
#       3 print('Combined Data results no min/max leaf')
# ----> 4 models_no_leaf_sample = tests.many_models_no_leaf(X_train2,y_train2,X_test2,y_test2)
#
# File c:\Users\nick\Desktop\AI_Bootcamp\group_projects\group-project-2\models.py:1298, in many_models_no_leaf(x, y, xt, yt)
#    1293 for s in split:
#    1294
#    1295     # Create Random Forest Classifier instance with depth
#    1296     model = RandomForestClassifier(max_depth=models_df['max_depth'].iloc[0],n_estimators=estimators_df['n_estimators'].iloc[0],min_samples_split=s,random_state=13)
# -> 1298     # Fit model
#    1299     model.fit(x,y)
#    1301     # Predict
#
# File c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\ensemble\_forest.py:456, in BaseForest.fit(self, X, y, sample_weight)
#     445 trees = [
#     446     self._make_estimator(append=False, random_state=random_state)
#     447     for i in range(n_more_estimators)
#     448 ]
#     450 # Parallel loop: we prefer the threading backend as the Cython code
#     451 # for fitting the trees is internally releasing the Python GIL
#     452 # making threading more efficient than multiprocessing in
#     453 # that case. However, for joblib 0.12+ we respect any
#     454 # parallel_backend contexts set at a higher level,
#     455 # since correctness does not rely on using threads.
# --> 456 trees = Parallel(
#     457     n_jobs=self.n_jobs,
#     458     verbose=self.verbose,
#     459     prefer="threads",
#     460 )(
#     461     delayed(_parallel_build_trees)(
#     462         t,
#     463         self.bootstrap,
#     464         X,
#     465         y,
#     466         sample_weight,
#     467         i,
#     468         len(trees),
#     469         verbose=self.verbose,
#     470         class_weight=self.class_weight,
#     471         n_samples_bootstrap=n_samples_bootstrap,
#     472     )
#     473     for i, t in enumerate(trees)
#     474 )
#     476 # Collect newly grown trees
#     477 self.estimators_.extend(trees)
#
# File c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\nick\.conda\envs\dev\lib\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File c:\Users\nick\.conda\envs\dev\lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File c:\Users\nick\.conda\envs\dev\lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File c:\Users\nick\.conda\envs\dev\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\nick\.conda\envs\dev\lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File c:\Users\nick\.conda\envs\dev\lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\nick\.conda\envs\dev\lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\ensemble\_forest.py:188, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     185     elif class_weight == "balanced_subsample":
#     186         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 188     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     189 else:
#     190     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\tree\_classes.py:959, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     928 @_fit_context(prefer_skip_nested_validation=True)
#     929 def fit(self, X, y, sample_weight=None, check_input=True):
#     930     """Build a decision tree classifier from the training set (X, y).
#     931
#     932     Parameters
#    (...)
#     956         Fitted estimator.
#     957     """
# --> 959     super()._fit(
#     960         X,
#     961         y,
#     962         sample_weight=sample_weight,
#     963         check_input=check_input,
#     964     )
#     965     return self
#
# File c:\Users\nick\.conda\envs\dev\lib\site-packages\sklearn\tree\_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
# Run combined data through many_models_min_leaf function to determine if ' min leaf' parameter setting is worth extra time.
# score and optimize Random Forest Classifier Model
print('Combined Data results min leaf')
models_min_leaf_sample = tests.many_models_min_leaf(X_train2,y_train2,X_test2,y_test2)

# %%
# Run combined data through many_models_max_leaf function to determine if 'no max leaf' parameter setting is worth extra time.
# score and optimize Random Forest Classifier Model
print('Combined Data results max leaf')
models_max_leaf_sample = tests.many_models_max_leaf(X_train2,y_train2,X_test2,y_test2)
