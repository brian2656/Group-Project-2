# %%
# import dependencies
import pandas as pd
from sklearn.model_selection import train_test_split
import models as tests

# %%
# Read in data as dataframe and show results
df = pd.read_csv('../datasets/winequality-red.csv',sep=';')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
print(f'null check \n{df.isnull().sum()}')
# Out:
# null check
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# creating threshold for bad category
threshold = 6
df['quality'] = df['quality'].where(df['quality'] > threshold, other=0)

# check quality column for unique value changes
print(df['quality'].unique())
# Out:
# [0 7 8]

# %%
# create threshold for good category
threshold = 7
df['quality'] = df['quality'].where(df['quality'] < threshold, other=1)

# check quality column for value changes
print(df['quality'].unique())
# Out:
# [0 1]

# %%
# Set X and y variables
X = df.drop(columns=['quality','fixed acidity','citric acid'])
y = df['quality']
# view X and y
print(f'X values: \n{X.head()}\n \ny values: \n{y}')
# Out:
# X values:
#    volatile acidity  residual sugar  chlorides  free sulfur dioxide  \
# 0              0.70             1.9      0.076                 11.0
# 1              0.88             2.6      0.098                 25.0
# 2              0.76             2.3      0.092                 15.0
# 3              0.28             1.9      0.075                 17.0
# 4              0.70             1.9      0.076                 11.0
#
#    total sulfur dioxide  density    pH  sulphates  alcohol
# 0                  34.0   0.9978  3.51       0.56      9.4
# 1                  67.0   0.9968  3.20       0.68      9.8
# 2                  54.0   0.9970  3.26       0.65      9.8
# 3                  60.0   0.9980  3.16       0.58      9.8
# 4                  34.0   0.9978  3.51       0.56      9.4
#
# y values:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1599, dtype: int64

# %%
# Split Data into training and test sets
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=13)

# %%
# Use imported 'many_models' function to run through initial models
wine_qt_models1 = tests.many_models_min_leaf(X_train,y_train,X_test,y_test)
# Out:
# Random Forest
# Test Accuracy: 0.905
# balanced test score: 0.730961791831357
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95       345
#            1       0.73      0.49      0.59        55
#
#     accuracy                           0.91       400
#    macro avg       0.83      0.73      0.77       400
# weighted avg       0.90      0.91      0.90       400
#
#
# Gradient Boost
# Test Accuracy: 0.89
# balanced test score: 0.691699604743083
#
#  classification report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       345
#            1       0.66      0.42      0.51        55
#
#     accuracy                           0.89       400
#    macro avg       0.78      0.69      0.72       400
# weighted avg       0.88      0.89      0.88       400
#
#
# Logistic Regression
# Test Accuracy: 0.8775
# balanced test score: 0.6233201581027668
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       345
#            1       0.62      0.27      0.38        55
#
#     accuracy                           0.88       400
#    macro avg       0.76      0.62      0.66       400
# weighted avg       0.86      0.88      0.86       400
#
#
# Poly Support Vector
# Test Accuracy: 0.87
# Balanced test score: 0.5884057971014492
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       345
#            1       0.58      0.20      0.30        55
#
#     accuracy                           0.87       400
#    macro avg       0.73      0.59      0.61       400
# weighted avg       0.84      0.87      0.84       400
#
#
# ADA low estimators
# Test Accuracy: 0.87
# balanced test score: 0.6495388669301713
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93       345
#            1       0.54      0.35      0.42        55
#
#     accuracy                           0.87       400
#    macro avg       0.72      0.65      0.67       400
# weighted avg       0.85      0.87      0.86       400
#
#
# ADA
# Test Accuracy: 0.88
# balanced test score: 0.7393939393939394
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       345
#            1       0.57      0.55      0.56        55
#
#     accuracy                           0.88       400
#    macro avg       0.75      0.74      0.74       400
# weighted avg       0.88      0.88      0.88       400
#
#
# SVC Sigmoid
# Test Accuracy: 0.8425
# balanced test score: 0.6183135704874836
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       345
#            1       0.40      0.31      0.35        55
#
#     accuracy                           0.84       400
#    macro avg       0.65      0.62      0.63       400
# weighted avg       0.83      0.84      0.83       400
#
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# ADA boost                 0.999166      0.8800             0.739394
# Random Forest             0.999166      0.9050             0.730962
# Gradient Boosting         0.961635      0.8900             0.691700
# ADA Low Estimators        0.895746      0.8700             0.649539
# Logistic Regression       0.883236      0.8775             0.623320
# SVC sigmoid               0.828190      0.8425             0.618314
# SVC poly                  0.908257      0.8700             0.588406
#
#                      Balanced Difference
# Model Name
# ADA boost                       0.257520
# Random Forest                   0.265952
# Gradient Boosting               0.176742
# ADA Low Estimators              0.061016
# Logistic Regression             0.025313
# SVC sigmoid                    -0.040567
# SVC poly                        0.100735
#
# Random Forest Parameter Tuning:
#
# best depth balanced test score:
#     train_score  test_score  max_depth
# 11     0.996914    0.737154         12
# 12     0.996914    0.732411         13
# 18     0.996914    0.730962         19
# 13     0.996914    0.730962         14
# 16     0.996914    0.729513         17
# max depths:
# [12, 13, 19, 14, 17]
#
# best leaf balanced test score:
#    train_score  test_score  min_leaf
# 0     0.934703    0.708432         2
# 2     0.834491    0.688406         4
# 1     0.875097    0.680764         3
# 3     0.807389    0.673123         5
# 7     0.749423    0.644401         9
# best leaf
# [2, 4, 3, 5, 9]
#
# best n_estimators balanced test score:
#     train_score  test_score  n_estimators
# 12     0.924962    0.746245            26
# 28     0.931617    0.738603            58
# 19     0.928530    0.735705            40
# 18     0.928048    0.730962            38
# 21     0.934703    0.729513            44
# best n_estimators
# [26, 58, 40, 38, 44]
#
# best min_split balanced test score:
#    train_score  test_score  min_split
# 0     0.924962    0.746245          2
# 1     0.924962    0.746245          4
# 5     0.844908    0.697497         12
# 4     0.860822    0.686957         10
# 2     0.899788    0.676416          6
# best min_split
# [2, 4, 12, 10, 6]
#
#
# best results:
#             n_estimators  max_depth  min_samples_leaf  min_split  train_score
# test_score
# 0.746245              26         12                 2          2     0.924962
# 0.746245              26         12                 2          4     0.924962
# 0.738603              44         13                 2          4     0.937789
# 0.738603              58         12                 2          2     0.931617
# 0.738603              58         12                 2          4     0.931617
# ...                  ...        ...               ...        ...          ...
# 0.624769              26         14                 9         10     0.736113
# 0.624769              26         17                 9          2     0.736113
# 0.624769              26         17                 9          4     0.736113
# 0.624769              26         17                 9         12     0.736113
# 0.624769              26         14                 9          6     0.736113
#
# [625 rows x 5 columns]
# best n_estimators: 26
# best max_depth: 12
# best leaves: 2
# Best min_split: 2
#
# best Random Forest Tuned Parameters scores
#
#
# Best Random Forest Tuned Parameters Scores
# Test Accuracy: 0.905
# balanced test score: 0.7462450592885375
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       345
#            1       0.71      0.53      0.60        55
#
#     accuracy                           0.91       400
#    macro avg       0.82      0.75      0.78       400
# weighted avg       0.90      0.91      0.90       400
#
# Balanced Trained Score
# Model Name
# Tuned Random Forest    0.924962
# Name: Balanced Trained Score, dtype: float64
# Balanced Test Score
# Model Name
# Tuned Random Forest    0.746245
# Name: Balanced Test Score, dtype: float64
# updated comparison DataFrame
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Tuned Random Forest       0.978315      0.9050             0.746245
# ADA boost                 0.999166      0.8800             0.739394
# Random Forest             0.999166      0.9050             0.730962
# Gradient Boosting         0.961635      0.8900             0.691700
# ADA Low Estimators        0.895746      0.8700             0.649539
# Logistic Regression       0.883236      0.8775             0.623320
# SVC sigmoid               0.828190      0.8425             0.618314
# SVC poly                  0.908257      0.8700             0.588406
#
#                      Balanced Difference
# Model Name
# Tuned Random Forest             0.178717
# ADA boost                       0.257520
# Random Forest                   0.265952
# Gradient Boosting               0.176742
# ADA Low Estimators              0.061016
# Logistic Regression             0.025313
# SVC sigmoid                    -0.040567
# SVC poly                        0.100735

# %%
wine_qt_models2 = tests.many_models_full(X_train,y_train,X_test,y_test)
# Out:
# Random Forest
# Test Accuracy: 0.905
# balanced test score: 0.730961791831357
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95       345
#            1       0.73      0.49      0.59        55
#
#     accuracy                           0.91       400
#    macro avg       0.83      0.73      0.77       400
# weighted avg       0.90      0.91      0.90       400
#
#
# Gradient Boost
# Test Accuracy: 0.89
# balanced test score: 0.691699604743083
#
#  classification report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       345
#            1       0.66      0.42      0.51        55
#
#     accuracy                           0.89       400
#    macro avg       0.78      0.69      0.72       400
# weighted avg       0.88      0.89      0.88       400
#
#
# Logistic Regression
# Test Accuracy: 0.8775
# balanced test score: 0.6233201581027668
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       345
#            1       0.62      0.27      0.38        55
#
#     accuracy                           0.88       400
#    macro avg       0.76      0.62      0.66       400
# weighted avg       0.86      0.88      0.86       400
#
#
# Poly Support Vector
# Test Accuracy: 0.87
# Balanced test score: 0.5884057971014492
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       345
#            1       0.58      0.20      0.30        55
#
#     accuracy                           0.87       400
#    macro avg       0.73      0.59      0.61       400
# weighted avg       0.84      0.87      0.84       400
#
#
# ADA low estimators
# Test Accuracy: 0.87
# balanced test score: 0.6495388669301713
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93       345
#            1       0.54      0.35      0.42        55
#
#     accuracy                           0.87       400
#    macro avg       0.72      0.65      0.67       400
# weighted avg       0.85      0.87      0.86       400
#
#
# ADA
# Test Accuracy: 0.8725
# balanced test score: 0.6586297760210804
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93       345
#            1       0.56      0.36      0.44        55
#
#     accuracy                           0.87       400
#    macro avg       0.73      0.66      0.68       400
# weighted avg       0.86      0.87      0.86       400
#
#
# SVC Sigmoid
# Test Accuracy: 0.8425
# balanced test score: 0.6183135704874836
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       345
#            1       0.40      0.31      0.35        55
#
#     accuracy                           0.84       400
#    macro avg       0.65      0.62      0.63       400
# weighted avg       0.83      0.84      0.83       400
#
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             0.999166      0.9050             0.730962
# Gradient Boosting         0.961635      0.8900             0.691700
# ADA boost                 0.904921      0.8725             0.658630
# ADA Low Estimators        0.895746      0.8700             0.649539
# Logistic Regression       0.883236      0.8775             0.623320
# SVC sigmoid               0.828190      0.8425             0.618314
# SVC poly                  0.908257      0.8700             0.588406
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.265952
# Gradient Boosting               0.176742
# ADA boost                       0.075459
# ADA Low Estimators              0.061016
# Logistic Regression             0.025313
# SVC sigmoid                    -0.040567
# SVC poly                        0.100735
#
# Random Forest Parameter Tuning:
#
# best depth balanced test score:
#     train_score  test_score  max_depth
# 11     0.996914    0.737154         12
# 12     0.996914    0.732411         13
# 18     0.996914    0.730962         19
# 13     0.996914    0.730962         14
# 16     0.996914    0.729513         17
# max depths:
# [12, 13, 19, 14, 17]
#
# best min leaf balanced test score:
#    train_score  test_score  min_leaf
# 0     0.934703    0.708432         2
# 2     0.834491    0.688406         4
# 1     0.875097    0.680764         3
# 3     0.807389    0.673123         5
# 7     0.749423    0.644401         9
# best min leaf
# [2, 4, 3, 5, 9]
#
# best n_estimators balanced test score:
#     train_score  test_score  n_estimators
# 12     0.924962    0.746245            26
# 28     0.931617    0.738603            58
# 19     0.928530    0.735705            40
# 18     0.928048    0.730962            38
# 21     0.934703    0.729513            44
# best n_estimators
# [26, 58, 40, 38, 44]
#
# best min_split balanced test score:
#    train_score  test_score  min_split
# 0     0.924962    0.746245          2
# 1     0.924962    0.746245          4
# 5     0.844908    0.697497         12
# 4     0.860822    0.686957         10
# 2     0.899788    0.676416          6
# best min_split
# [2, 4, 12, 10, 6]
#
# best max_leaf balanced test score:
#     train_score  test_score  max_leaf
# 20     0.900270    0.702240        62
# 19     0.896702    0.694598        59
# 23     0.929012    0.693149        71
# 18     0.887442    0.693149        56
# 17     0.880787    0.693149        53
# best max leaf
# [62, 59, 71, 56, 53]
#
#
# Test best Random Forest Tuned Parameters scores
#
#
# Test Best Random Forest Tuned Parameters Scores
# Test Accuracy: 0.895
# balanced test score: 0.7022397891963109
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       345
#            1       0.69      0.44      0.53        55
#
#     accuracy                           0.90       400
#    macro avg       0.80      0.70      0.74       400
# weighted avg       0.88      0.90      0.88       400
#
# updated comparison DataFrame
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             0.999166      0.9050             0.730962
# Test Random Forest        0.971643      0.8950             0.702240
# Gradient Boosting         0.961635      0.8900             0.691700
# ADA boost                 0.904921      0.8725             0.658630
# ADA Low Estimators        0.895746      0.8700             0.649539
# Logistic Regression       0.883236      0.8775             0.623320
# SVC sigmoid               0.828190      0.8425             0.618314
# SVC poly                  0.908257      0.8700             0.588406
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.265952
# Test Random Forest              0.198030
# Gradient Boosting               0.176742
# ADA boost                       0.075459
# ADA Low Estimators              0.061016
# Logistic Regression             0.025313
# SVC sigmoid                    -0.040567
# SVC poly                        0.100735
#
# best results:
#             n_estimators  max_depth  min_split  max_leaf  min_samples_leaf  \
# test_score
# 0.705138              26         12         12        62                 2
# 0.705138              26         12         12        53                 2
# 0.705138              26         12         12        56                 2
# 0.705138              26         12         12        71                 2
# 0.705138              26         12         12        59                 2
# ...                  ...        ...        ...       ...               ...
# 0.635310              26         19         12        71                 9
# 0.635310              26         12          2        56                 9
# 0.635310              26         19         12        59                 9
# 0.635310              26         13          6        56                 9
# 0.635310              26         12          2        53                 9
#
#             train_score
# test_score
# 0.705138       0.847512
# 0.705138       0.847512
# 0.705138       0.847512
# 0.705138       0.847512
# 0.705138       0.847512
# ...                 ...
# 0.635310       0.742092
# 0.635310       0.742092
# 0.635310       0.742092
# 0.635310       0.742092
# 0.635310       0.742092
#
# [3125 rows x 6 columns]
#
# Top Best Parameters:
# best n_estimators: 26
# best max_depth: 12
# Best min_split: 12
# best max_leaf: 62
# best min_leaves: 2
#
#
# Best Random Forest Tuned Parameters Scores
# Test Accuracy: 0.9
# balanced test score: 0.7051383399209487
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       345
#            1       0.73      0.44      0.55        55
#
#     accuracy                           0.90       400
#    macro avg       0.82      0.71      0.74       400
# weighted avg       0.89      0.90      0.89       400
#
# Balanced Trained Score
# Model Name
# Tuned Random Forest    0.847512
# Name: Balanced Trained Score, dtype: float64
# Balanced Test Score
# Model Name
# Tuned Random Forest    0.705138
# Name: Balanced Test Score, dtype: float64
# updated comparison DataFrame
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             0.999166      0.9050             0.730962
# Tuned Random Forest       0.952460      0.9000             0.705138
# Test Random Forest        0.971643      0.8950             0.702240
# Gradient Boosting         0.961635      0.8900             0.691700
# ADA boost                 0.904921      0.8725             0.658630
# ADA Low Estimators        0.895746      0.8700             0.649539
# Logistic Regression       0.883236      0.8775             0.623320
# SVC sigmoid               0.828190      0.8425             0.618314
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.265952
# Tuned Random Forest             0.142374
# Test Random Forest              0.198030
# Gradient Boosting               0.176742
# ADA boost                       0.075459
# ADA Low Estimators              0.061016
# Logistic Regression             0.025313
# SVC sigmoid                    -0.040567

# %%
wine_qt_models3 = tests.many_models_max_leaf(X_train,y_train,X_test,y_test)
# Out:
# Random Forest
# Test Accuracy: 0.905
# balanced test score: 0.730961791831357
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95       345
#            1       0.73      0.49      0.59        55
#
#     accuracy                           0.91       400
#    macro avg       0.83      0.73      0.77       400
# weighted avg       0.90      0.91      0.90       400
#
#
# Gradient Boost
# Test Accuracy: 0.89
# balanced test score: 0.691699604743083
#
#  classification report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       345
#            1       0.66      0.42      0.51        55
#
#     accuracy                           0.89       400
#    macro avg       0.78      0.69      0.72       400
# weighted avg       0.88      0.89      0.88       400
#
#
# Logistic Regression
# Test Accuracy: 0.8775
# balanced test score: 0.6233201581027668
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       345
#            1       0.62      0.27      0.38        55
#
#     accuracy                           0.88       400
#    macro avg       0.76      0.62      0.66       400
# weighted avg       0.86      0.88      0.86       400
#
#
# Poly Support Vector
# Test Accuracy: 0.87
# Balanced test score: 0.5884057971014492
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       345
#            1       0.58      0.20      0.30        55
#
#     accuracy                           0.87       400
#    macro avg       0.73      0.59      0.61       400
# weighted avg       0.84      0.87      0.84       400
#
#
# ADA low estimators
# Test Accuracy: 0.87
# balanced test score: 0.6495388669301713
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93       345
#            1       0.54      0.35      0.42        55
#
#     accuracy                           0.87       400
#    macro avg       0.72      0.65      0.67       400
# weighted avg       0.85      0.87      0.86       400
#
#
# ADA
# Test Accuracy: 0.8725
# balanced test score: 0.6586297760210804
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93       345
#            1       0.56      0.36      0.44        55
#
#     accuracy                           0.87       400
#    macro avg       0.73      0.66      0.68       400
# weighted avg       0.86      0.87      0.86       400
#
#
# SVC Sigmoid
# Test Accuracy: 0.8425
# balanced test score: 0.6183135704874836
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       345
#            1       0.40      0.31      0.35        55
#
#     accuracy                           0.84       400
#    macro avg       0.65      0.62      0.63       400
# weighted avg       0.83      0.84      0.83       400
#
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             0.999166      0.9050             0.730962
# Gradient Boosting         0.961635      0.8900             0.691700
# ADA boost                 0.904921      0.8725             0.658630
# ADA Low Estimators        0.895746      0.8700             0.649539
# Logistic Regression       0.883236      0.8775             0.623320
# SVC sigmoid               0.828190      0.8425             0.618314
# SVC poly                  0.908257      0.8700             0.588406
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.265952
# Gradient Boosting               0.176742
# ADA boost                       0.075459
# ADA Low Estimators              0.061016
# Logistic Regression             0.025313
# SVC sigmoid                    -0.040567
# SVC poly                        0.100735
#
# Random Forest Parameter Tuning:
#
# best depth balanced test score:
#     train_score  test_score  max_depth
# 11     0.996914    0.737154         12
# 12     0.996914    0.732411         13
# 18     0.996914    0.730962         19
# 13     0.996914    0.730962         14
# 16     0.996914    0.729513         17
# max depths:
# [12, 13, 19, 14, 17]
#
#
# best n_estimators balanced test score:
#     train_score  test_score  n_estimators
# 15     0.990741    0.765876            32
# 14     0.987654    0.765876            30
# 25     0.990741    0.765876            52
# 24     0.990741    0.765876            50
# 18     0.993827    0.758235            38
# best n_estimators
# [32, 30, 52, 50, 38]
#
# best min_split balanced test score:
#    train_score  test_score  min_split
# 0     0.990741    0.765876          2
# 1     0.953222    0.758235          4
# 3     0.909530    0.721871          8
# 2     0.940394    0.703689          6
# 7     0.854650    0.676416         16
# best min_split
# [2, 4, 8, 6, 16]
#
# best max_leaf balanced test score:
#      train_score  test_score  max_leaf
# 166     0.984568    0.714229       500
# 229     0.984568    0.714229       689
# 227     0.984568    0.714229       683
# 226     0.984568    0.714229       680
# 225     0.984568    0.714229       677
# best max leaf
# [500, 689, 683, 680, 677]
#
#
# Test best Random Forest Tuned Parameters scores "max leaf"
#
#
# Test Best Random Forest Tuned Parameters Scores
# Test Accuracy: 0.9025
# balanced test score: 0.7142292490118577
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95       345
#            1       0.74      0.45      0.56        55
#
#     accuracy                           0.90       400
#    macro avg       0.83      0.71      0.75       400
# weighted avg       0.89      0.90      0.89       400
#
# updated comparison DataFrame
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             0.999166      0.9050             0.730962
# Test Random Forest        0.995830      0.9025             0.714229
# Gradient Boosting         0.961635      0.8900             0.691700
# ADA boost                 0.904921      0.8725             0.658630
# ADA Low Estimators        0.895746      0.8700             0.649539
# Logistic Regression       0.883236      0.8775             0.623320
# SVC sigmoid               0.828190      0.8425             0.618314
# SVC poly                  0.908257      0.8700             0.588406
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.265952
# Test Random Forest              0.270339
# Gradient Boosting               0.176742
# ADA boost                       0.075459
# ADA Low Estimators              0.061016
# Logistic Regression             0.025313
# SVC sigmoid                    -0.040567
# SVC poly                        0.100735
#
# best results:
#             n_estimators  max_depth  min_split  max_leaf  train_score
# test_score
# 0.724769              30         19          2       500     0.993827
# 0.724769              30         19          2       677     0.993827
# 0.724769              30         19          2       683     0.993827
# 0.724769              30         19          2       689     0.993827
# 0.724769              30         17          2       500     0.993827
# ...                  ...        ...        ...       ...          ...
# 0.650593              32         13         16       680     0.836613
# 0.650593              32         13         16       683     0.836613
# 0.650593              32         13         16       689     0.836613
# 0.650593              32         13         16       500     0.836613
# 0.650593              32         13         16       677     0.836613
#
# [625 rows x 5 columns]
#
# Top Best Parameters:
# best n_estimators: 30
# best max_depth: 19
# Best min_split: 2
# best max_leaf: 500
# best Random Forest Tuned Parameters scores "max leaf"
#
#
# Best Random Forest Tuned Parameters Scores
# Test Accuracy: 0.9075
# balanced test score: 0.7247694334650856
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       345
#            1       0.76      0.47      0.58        55
#
#     accuracy                           0.91       400
#    macro avg       0.84      0.72      0.77       400
# weighted avg       0.90      0.91      0.90       400
#
# Balanced Trained Score
# Model Name
# Tuned Random Forest    0.993827
# Name: Balanced Trained Score, dtype: float64
# Balanced Test Score
# Model Name
# Tuned Random Forest    0.724769
# Name: Balanced Test Score, dtype: float64
# updated comparison DataFrame
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             0.999166      0.9050             0.730962
# Tuned Random Forest       0.998332      0.9075             0.724769
# Test Random Forest        0.995830      0.9025             0.714229
# Gradient Boosting         0.961635      0.8900             0.691700
# ADA boost                 0.904921      0.8725             0.658630
# ADA Low Estimators        0.895746      0.8700             0.649539
# Logistic Regression       0.883236      0.8775             0.623320
# SVC sigmoid               0.828190      0.8425             0.618314
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.265952
# Tuned Random Forest             0.269058
# Test Random Forest              0.270339
# Gradient Boosting               0.176742
# ADA boost                       0.075459
# ADA Low Estimators              0.061016
# Logistic Regression             0.025313
# SVC sigmoid                    -0.040567

# %%
models_no_leaf = tests.many_models_no_leaf(X_train,y_train,X_test,y_test)
# Out:
# Random Forest
# Test Accuracy: 0.905
# balanced test score: 0.730961791831357
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95       345
#            1       0.73      0.49      0.59        55
#
#     accuracy                           0.91       400
#    macro avg       0.83      0.73      0.77       400
# weighted avg       0.90      0.91      0.90       400
#
#
# Gradient Boost
# Test Accuracy: 0.89
# balanced test score: 0.691699604743083
#
#  classification report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       345
#            1       0.66      0.42      0.51        55
#
#     accuracy                           0.89       400
#    macro avg       0.78      0.69      0.72       400
# weighted avg       0.88      0.89      0.88       400
#
#
# Logistic Regression
# Test Accuracy: 0.8775
# balanced test score: 0.6233201581027668
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       345
#            1       0.62      0.27      0.38        55
#
#     accuracy                           0.88       400
#    macro avg       0.76      0.62      0.66       400
# weighted avg       0.86      0.88      0.86       400
#
#
# Poly Support Vector
# Test Accuracy: 0.87
# Balanced test score: 0.5884057971014492
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       345
#            1       0.58      0.20      0.30        55
#
#     accuracy                           0.87       400
#    macro avg       0.73      0.59      0.61       400
# weighted avg       0.84      0.87      0.84       400
#
#
# ADA low estimators
# Test Accuracy: 0.87
# balanced test score: 0.6495388669301713
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93       345
#            1       0.54      0.35      0.42        55
#
#     accuracy                           0.87       400
#    macro avg       0.72      0.65      0.67       400
# weighted avg       0.85      0.87      0.86       400
#
#
# ADA
# Test Accuracy: 0.8725
# balanced test score: 0.6586297760210804
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93       345
#            1       0.56      0.36      0.44        55
#
#     accuracy                           0.87       400
#    macro avg       0.73      0.66      0.68       400
# weighted avg       0.86      0.87      0.86       400
#
#
# SVC Sigmoid
# Test Accuracy: 0.8425
# balanced test score: 0.6183135704874836
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       345
#            1       0.40      0.31      0.35        55
#
#     accuracy                           0.84       400
#    macro avg       0.65      0.62      0.63       400
# weighted avg       0.83      0.84      0.83       400
#
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Random Forest             0.999166      0.9050             0.730962
# Gradient Boosting         0.961635      0.8900             0.691700
# ADA boost                 0.904921      0.8725             0.658630
# ADA Low Estimators        0.895746      0.8700             0.649539
# Logistic Regression       0.883236      0.8775             0.623320
# SVC sigmoid               0.828190      0.8425             0.618314
# SVC poly                  0.908257      0.8700             0.588406
#
#                      Balanced Difference
# Model Name
# Random Forest                   0.265952
# Gradient Boosting               0.176742
# ADA boost                       0.075459
# ADA Low Estimators              0.061016
# Logistic Regression             0.025313
# SVC sigmoid                    -0.040567
# SVC poly                        0.100735
#
# Random Forest Parameter Tuning:
#
# best depth balanced test score:
#     train_score  test_score  max_depth
# 11     0.996914    0.737154         12
# 12     0.996914    0.732411         13
# 18     0.996914    0.730962         19
# 13     0.996914    0.730962         14
# 16     0.996914    0.729513         17
# max depths:
# [12, 13, 19, 14, 17]
#
#
# best n_estimators balanced test score:
#     train_score  test_score  n_estimators
# 15     0.990741    0.765876            32
# 14     0.987654    0.765876            30
# 25     0.990741    0.765876            52
# 24     0.990741    0.765876            50
# 18     0.993827    0.758235            38
# best n_estimators
# [32, 30, 52, 50, 38]
#
# best min_split balanced test score:
#    train_score  test_score  min_split
# 0     0.990741    0.765876          2
# 1     0.953222    0.758235          4
# 3     0.909530    0.721871          8
# 2     0.940394    0.703689          6
# 7     0.854650    0.676416         16
# best min_split
# [2, 4, 8, 6, 16]
#
#
# Test best Random Forest Tuned Parameters scores "max leaf"
#
#
# Test Best Random Forest Tuned Parameters Scores
# Test Accuracy: 0.9125
# balanced test score: 0.7658761528326745
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       345
#            1       0.74      0.56      0.64        55
#
#     accuracy                           0.91       400
#    macro avg       0.84      0.77      0.79       400
# weighted avg       0.91      0.91      0.91       400
#
# updated comparison DataFrame
#                      Trained Score  Test Score  Balanced Test Score  \
# Model Name
# Test Random Forest        0.997498      0.9125             0.765876
# Random Forest             0.999166      0.9050             0.730962
# Gradient Boosting         0.961635      0.8900             0.691700
# ADA boost                 0.904921      0.8725             0.658630
# ADA Low Estimators        0.895746      0.8700             0.649539
# Logistic Regression       0.883236      0.8775             0.623320
# SVC sigmoid               0.828190      0.8425             0.618314
# SVC poly                  0.908257      0.8700             0.588406
#
#                      Balanced Difference
# Model Name
# Test Random Forest              0.224865
# Random Forest                   0.265952
# Gradient Boosting               0.176742
# ADA boost                       0.075459
# ADA Low Estimators              0.061016
# Logistic Regression             0.025313
# SVC sigmoid                    -0.040567
# SVC poly                        0.100735
#
# best results:
#             n_estimators  max_depth  min_split  train_score
# test_score
# 0.767325              30         17          4     0.966049
# 0.767325              32         14          4     0.969136
# 0.767325              30         19          4     0.966049
# 0.765876              32         12          2     0.990741
# 0.765876              50         12          2     0.990741
# ...                  ...        ...        ...          ...
# 0.642951              50         19         16     0.839217
# 0.640053              30         13         16     0.832562
# 0.640053              32         17         16     0.844908
# 0.640053              32         14         16     0.842304
# 0.640053              32         19         16     0.844908
#
# [125 rows x 4 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 models_no_leaf = tests.many_models_no_leaf(X_train,y_train,X_test,y_test)
#
# File c:\Users\nick\Desktop\AI_Bootcamp\group_projects\group-project-2\models\models.py:1695, in many_models_no_leaf(x, y, xt, yt)
#    1691 best_d = best_results_df['max_depth'].iloc[0]
#    1692 best_s = best_results_df['min_split'].iloc[0]
# -> 1695 print(f'\nTop Best Parameters: \nbest n_estimators: {best_n} \nbest max_depth: {best_d} \nBest min_split: {best_s} \nbest max_leaf: {best_a}')
#    1697 # Create random forest instance with best parameters
#    1698 tuned_rf = RandomForestClassifier(n_estimators=best_results_df['n_estimators'].iloc[0], max_depth=best_results_df['max_depth'].iloc[0],max_leaf_nodes=best_results_df['max_leaf'].iloc[0],min_samples_split=best_results_df['min_split'].iloc[0],random_state=13)
#
# NameError: name 'best_a' is not defined
